# %%
# pandas visulaization vs Matplolib vs Seaborn

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('heart.csv')
df
# Out:
#      age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63       1   3       145   233    1        0      150      0      2.3
# 1     37       1   2       130   250    0        1      187      0      3.5
# 2     41       0   1       130   204    0        0      172      0      1.4
# 3     56       1   1       120   236    0        1      178      0      0.8
# 4     57       0   0       120   354    0        1      163      1      0.6
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57       0   0       140   241    0        1      123      1      0.2
# 299   45       1   3       110   264    0        1      132      0      1.2
# 300   68       1   0       144   193    1        1      141      0      3.4
# 301   57       1   0       130   131    0        1      115      1      1.2
# 302   57       0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# ...

# %%
ages=df.groupby('age').median().reset_index()
ages
# Out:
#     age  gender   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    29     1.0  1.0     130.0  204.0  0.0      0.0    202.0    0.0     0.00
# 1    34     0.5  2.0     118.0  196.0  0.0      0.5    183.0    0.0     0.35
# 2    35     1.0  0.0     124.0  195.0  0.0      1.0    165.0    0.5     0.70
# 3    37     0.5  2.0     125.0  232.5  0.0      1.0    178.5    0.0     1.75
# 4    38     1.0  2.0     138.0  175.0  0.0      1.0    173.0    0.0     0.00
# 5    39     0.5  2.0     128.0  219.5  0.0      1.0    165.5    0.0     0.00
# 6    40     1.0  0.0     140.0  199.0  0.0      1.0    178.0    1.0     1.40
# 7    41     1.0  1.0     116.0  209.0  0.0      1.0    168.0    0.0     0.00
# 8    42     1.0  1.5     125.0  242.0  0.0      1.0    167.5    0.0     0.30
# 9    43     1.0  0.0     126.0  247.0  0.0      1.0    161.5    0.0     1.35
# 10   44     1.0  1.0     120.0  226.0  0.0      1.0    173.0    0.0     0.00
# ...

# %%
# Simple Pandas
ages.plot.line('age', 'chol')
plt.show()

# %%
# matplotlib
fig, ax = plt.subplots()
ax.plot(ages['age'], ages['chol'], ls=':', lw=1.7)  # line style , line width
ax.set_xlabel('Age')
ax.set_ylabel('Cholestrol')
plt.show()

# %%
# seaborn

sns.lineplot(x='age', y='chol', data=ages, linestyle=':', linewidth=1.7)
plt.xlabel('Age')
plt.ylabel('Cholestrol')
plt.show()

# %%
## lab exam questions
# Data Cleaning
# Remove unnecessary rows/columsn
# misssing data
# Tackle missing data
# Drop Records
# impute With Constants
# Impute With Statistics and missing indicators
